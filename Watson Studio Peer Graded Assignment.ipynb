# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Nwabuokei Chukwudi Raymond
#     Data Scientist

# %% [markdown]
# *I am interested in data science because i want make an impactful insight in the tech world

# %% [markdown]
# ### the next code will output 2 plus 3

# %%
print(2 + 3)
# Out:
# 5

# %% [markdown]
# ---
# * Orange
# * Mango
# * APPLE
# >These are fruits
# <img>![some-fruits-19896264.jpg](attachment:some-fruits-19896264.jpg)
# <src=https://www.dreamstime.com/stock-images-some-fruits-image19896264
